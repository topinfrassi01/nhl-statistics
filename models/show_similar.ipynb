# %%
import pandas
from typing import Sequence
from data_preparation.prepare_data_knn import prepare
from models.similar_players import ClosestComparableFinder
from sklearn.neighbors import NearestNeighbors
from pathlib import Path
from operator import itemgetter

# %%
ccf = ClosestComparableFinder(Path('stats'), k=5)

# %%
observed_season = "2017-2018"
observed_player_name = "Max Domi"

player, results = ccf.get_closest_players(observed_season, observed_player_name)

pandas.concat([player, results])
# Out:
#                      #   Season Team Shoots Pos  GP   G   A   P  +/-  ...  \
# Max Domi           146  2017-18  ARI      L   C  82   9  36  45   -7  ...
# Max Domi           184  2016-17  ARI      L   C  59   9  29  38   -9  ...
# Matthew Tkachuk    112  2016-17  CGY      L   L  76  13  35  48   14  ...
# Jesper Bratt       237  2018-19  NJD      L   L  51   8  25  33   -8  ...
# Sean Couturier     169  2015-16  PHI      L   C  63  11  28  39    8  ...
# Mathieu Perreault  151  2015-16  WPG      L   C  71   9  32  41  -11  ...
#
#                    PPG  PPP  SHG  SHP  OTG  GWG    S   S%  TOI/GP  FOW%
# Max Domi             1    9    0    0    0    0  150  6.0   16:42  44.9
# Max Domi             1    8    0    0    0    1  108  8.3   16:59  50.0
# Matthew Tkachuk      3   13    0    0    0    2  142  9.2   14:40  34.8
# Jesper Bratt         1    8    0    0    0    1   91  8.8   15:10  57.1
# Sean Couturier       2    7    0    1    0    1  119  9.2   18:36  48.6
# ...

# %%
import pandas

# %%
df=pandas.read_csv('../statistics/2021-2022.csv',header=0, encoding='unicode_escape')

# %%
df=df.set_index('Player')

# %%
df.loc["Sebastian Aho"]
# Out:
#                  #   Season Team Shoots Pos  GP   G   A   P  +/-  ...  PPG  \
# Player                                                            ...
# Sebastian Aho   12  2021-22  CAR      L   C  28  15  19  34   12  ...    6
# Sebastian Aho  676  2021-22  NYI      L   D  12   0   2   2   -6  ...    0
#
#                PPP  SHG  SHP  OTG  GWG   S    S%  TOI/GP  FOW%
# Player
# Sebastian Aho   10    0    2    1    1  90  16.7   19:26  55.0
# Sebastian Aho    1    0    0    0    0  17   0.0   17:17    --
#
# [2 rows x 24 columns]

# %%
df[df.duplicated()== False]
# Out:
#                       #   Season Team Shoots Pos  GP   G   A   P  +/-  ...  \
# Player                                                                 ...
# Connor McDavid        1  2021-22  EDM      L   C  32  19  34  53    6  ...
# Leon Draisaitl        2  2021-22  EDM      L   C  32  25  27  52    9  ...
# Alex Ovechkin         3  2021-22  WSH      R   L  34  24  26  50   19  ...
# Jonathan Huberdeau    4  2021-22  FLA      L   L  32  11  30  41   10  ...
# Steven Stamkos        5  2021-22  TBL      R   C  33  16  23  39    5  ...
# ...                 ...      ...  ...    ...  ..  ..  ..  ..  ..  ...  ...
# Justin Bailey       796  2021-22  VAN      R   R  10   0   0   0   -4  ...
# Madison Bowey       797  2021-22  VAN      R   D   2   0   0   0   -3  ...
# Frederik Gauthier   798  2021-22  NJD      L   C   8   0   0   0   -1  ...
# Brandon Baddock     799  2021-22  MTL      L   L   1   0   0   0    0  ...
# ...
